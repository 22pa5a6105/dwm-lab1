# %% [markdown]
# <a href="https://colab.research.google.com/github/22pa5a6105/dwm-lab1/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({"roll no":["101","102","103"],"name":["ravi","siva","raju"]})
df
# Out:
#   roll no  name
# 0     101  ravi
# 1     102  siva
# 2     103  raju

# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Copy of students_placement_data.csv")
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                      True
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0          1      M       A            87.3                     65.30
# 1          2      F       A            89.0                     92.40
# 2          3      F       A            67.0                     40.20
# 3          4      M       A            71.0                     70.40
# 4          5      M       A            44.0                     65.50
# ..       ...    ...     ...             ...                       ...
# 112      113      M       B            81.1                     78.60
# 113      114      M       B            81.3                     85.12
# 114      115      M       B            83.5                     89.90
# 115      116      M       B            85.5                     90.63
# 116      117      M       B            80.0                     83.33
#
#      B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0                40.00        18                                 NO
# 1                21.20         0                                yes
# 2                  NaN        13                                yes
# 3                36.47        17                                yes
# 4                42.52        17                                yes
# ..                 ...       ...                                ...
# 112              35.84        16                                 NO
# 113              68.50         0                                 NO
# 114              76.30         0                                 NO
# 115              74.50         0                                 NO
# 116              65.53         0                                 NO
#
#     placement status
# 0         Not placed
# 1             Placed
# 2         Not placed
# 3         Not placed
# 4         Not placed
# ..               ...
# 112       Not placed
# 113       Not placed
# 114       Not placed
# 115       Not placed
# 116       Not placed
#
# [117 rows x 9 columns]>

# %%
df.shape
# Out:
# (117, 9)

# %%
import plotly.express as px
cut_counts = df['Gender'].value_counts()
fig = px.bar(x=cut_counts.index, y=cut_counts.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f319b4fe-fcb8-418a-a414-2bfb3806fb9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f319b4fe-fcb8-418a-a414-2bfb3806fb9c")) {                    Plotly.newPlot(                        "f319b4fe-fcb8-418a-a414-2bfb3806fb9c",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["M","F"],"xaxis":"x","y":[68,49],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
import numpy as np
pd.pivot_table(df, values='B.Tech_percentage', index='Gender', columns='placement status',aggfunc=np.mean)
# Out:
# placement status  Not placed     Placed
# Gender
# F                  66.360526  73.531379
# M                  54.825345  69.574000

# %%
pd.crosstab(index=df['Gender'], columns=df['placement status'])
# Out:
# placement status  Not placed  Placed
# Gender
# F                         20      29
# M                         58      10

# %%
from sklearn.preprocessing import StandardScaler

# %%
cols_to_scale =['SSC Percentage','inter_Diploma_percentage','B.Tech_percentage']

Scaler =StandardScaler()
Scaler.fit(df[cols_to_scale])
df[cols_to_scale] = Scaler.transform(df[cols_to_scale])
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A        0.758550                 -1.294643
# 1        2      F       A        0.938989                  1.008221
# 2        3      F       A       -1.396109                 -3.427555
# 3        4      M       A       -0.971545                 -0.861263
# 4        5      M       A       -3.837348                 -1.277648
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0          -1.807695        18                                 NO
# 1          -3.307283         0                                yes
# 2                NaN        13                                yes
# 3          -2.089267        17                                yes
# 4          -1.606687        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
from sklearn.preprocessing import MinMaxScaler
cols_to_scale =['SSC Percentage','inter_Diploma_percentage','B.Tech_percentage']
Scaler = MinMaxScaler(feature_range=(0,5))
Scaler.fit(df[cols_to_scale])
df[cols_to_scale] = Scaler.transform(df[cols_to_scale])
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A        4.359646                  2.213404
# 1        2      F       A        4.530810                  4.603175
# 2        3      F       A        2.315747                  0.000000
# 3        4      M       A        2.718486                  2.663139
# 4        5      M       A        0.000000                  2.231041
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0           1.405082        18                                 NO
# 1           0.000000         0                                yes
# 2                NaN        13                                yes
# 3           1.141256        17                                yes
# 4           1.593423        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
X=df[["Gender","Section","SSC Percentage","inter_Diploma_percentage","B.Tech_percentage","Backlogs","registered_for_ Placement_Training"]].values

# %%
y=df["placement status"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train.shape
# Out:
# (93, 7)

# %%
X_test.shape
# Out:
# (24, 7)

# %%
y_train.shape
# Out:
# (93,)

# %%
y_test.shape
# Out:
# (24,)
